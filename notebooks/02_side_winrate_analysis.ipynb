# %% [markdown]
# # Side Win Rate Analysis
#
# ## 분석 목적
#
# 본 노트북에서는 Oracle's Elixir 2025년 LoL 프로 경기 데이터를 활용하여
# 블루 사이드와 레드 사이드의 승률 차이를 분석한다.
#
# 주요 질문은 다음과 같다.
#
# - 2025년 전체 경기에서 블루 사이드의 승률은 레드 사이드보다 높은가?
# - 주요 4대 리그(LCK, LPL, LEC, LCS)에서도 같은 경향이 나타나는가?
# - 진영별 승률 차이가 단순 우연인지, 통계적으로 검토할 수 있는가?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %% [markdown]
# **processed data 가져오기**

# %%
DATA_PATH = Path("../data/processed/major_leagues_2025.csv")
major_df = pd.read_csv(DATA_PATH)
major_df.head()
# Out:
#              gameid datacompleteness  url league  year split  playoffs  \
# 0  LOLTMNT03_183532         complete  NaN    LCK  2025   Cup         0
# 1  LOLTMNT03_183532         complete  NaN    LCK  2025   Cup         0
# 2  LOLTMNT03_183538         complete  NaN    LCK  2025   Cup         0
# 3  LOLTMNT03_183538         complete  NaN    LCK  2025   Cup         0
# 4  LOLTMNT03_183544         complete  NaN    LCK  2025   Cup         0
#
#                   date  game  patch  ...  golddiffat25 xpdiffat25 csdiffat25  \
# 0  2025-01-15 08:09:30     1  15.01  ...        6526.0     5253.0       69.0
# 1  2025-01-15 08:09:30     1  15.01  ...       -6526.0    -5253.0      -69.0
# 2  2025-01-15 09:03:08     2  15.01  ...        5646.0     3268.0      -13.0
# 3  2025-01-15 09:03:08     2  15.01  ...       -5646.0    -3268.0       13.0
# 4  2025-01-15 09:54:37     3  15.01  ...        3574.0     2125.0       23.0
#
#    killsat25  assistsat25 deathsat25 opp_killsat25  opp_assistsat25  \
# ...
